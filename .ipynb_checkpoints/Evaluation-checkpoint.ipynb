# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_loader.data_loader import PhageLoader
from torch.utils.data.sampler import SequentialSampler
from torch.utils.data import Subset
import seaborn as sns
import math
import json
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import datetime
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score,roc_curve,auc

sns.set(rc={'figure.figsize':(15,10)})

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Network class (this might be better off in a separate file)

# %%
class GRU(nn.Module):
    def __init__(self, vocab_size, embedding_size, hidden_size, output_labels, number_of_layers=1, bidirectional=True, weights_matrix=None):
        super(GRU, self).__init__()
        
        self.bidirectional = bidirectional
        self.hidden_dim_dense = hidden_size
        self.num_layers = number_of_layers 
        if bidirectional:
            self.hidden_dim_dense = hidden_size * 2
        if len(weights_matrix.size())!=0:
            self.emb_layer = self.create_emb_layer(weights_matrix,True)          
        else:
            self.emb_layer = nn.Embedding(vocab_size, embedding_size)
            
        self.gru = nn.GRU(input_size=embedding_size, hidden_size=hidden_size, bidirectional=bidirectional, num_layers=number_of_layers,batch_first=True)
        self.linear = nn.Linear(self.hidden_dim_dense, int(self.hidden_dim_dense/2))
        self.linear2 = nn.Linear(int(self.hidden_dim_dense/2),output_labels)
        
    def forward(self, h_t1, indexes):
        #indexes -> (batch,seq_length)
        embedding = self.emb_layer(indexes)
        #print("EMBEDDING SHAPE: ", embedding.size())
        #embedding -> (batch,seq_length,embedding_size)
        out,h_t = self.gru(embedding, h_t1)
        #print("OUT SHAPE: ", out.size(), self.hidden_dim_dense)
        #out -> ()
        #out = out.view(self.hidden_dim_dense, -1)
        
        out = F.relu(self.linear(out))
        out = self.linear2(out)
        out = F.log_softmax(out,dim=2)
        
        return out,h_t
        
    def initHidden(self, batch_size, hidden_size):      
        if self.bidirectional:
            return torch.randn(self.num_layers*2, batch_size, hidden_size, device=device)
        else:
            return torch.randn(self.num_layers, batch_size, hidden_size, device=device)


    def create_emb_layer(self, weights_matrix, non_trainable=True):
        num_embeddings, embedding_dim = weights_matrix.size()
        emb_layer = nn.Embedding(num_embeddings, embedding_dim)
        emb_layer.load_state_dict({'weight': weights_matrix})
        if non_trainable:
            emb_layer.weight.requires_grad = False
        return emb_layer

# %% [markdown]
# ## Output file (for computing metrics)

# %%
def split_sets(dataset,batch_size,ids=False):
    n = len(dataset)  # how many total elements you have
    test_size = .1
    n_test = int( n * test_size )  # number of test/val elements
    n_train = n - 2 * n_test

    idx = list(range(n))  # indices to all elements
    train_idx = idx[:n_train]
    val_idx = idx[n_train:(n_train + n_test)]
    test_idx = idx[(n_train + n_test):]

    train_dataset = Subset(dataset,train_idx)
    valid_dataset = Subset(dataset,val_idx)
    test_dataset = Subset(dataset,test_idx)
    a = batch_size 

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=a, drop_last=True)
    validation_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=a,drop_last=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=a, drop_last=True)
    if ids:
        return (train_loader,train_idx), (validation_loader,val_idx), (test_loader,test_idx)
    else:
        return train_loader, validation_loader, test_loader

# %%
def get_results_formatted(folder='models_grid/',model_name='model5',epoch=100):
    
    model_selected = model_name+'_'+str(epoch)
    print(model_selected)
    model = torch.load(folder + model_selected,map_location='cpu')
    loader = PhageLoader("data/")
    
    configuration = model_name+'.json'
    f = open(folder + configuration)
    config = json.load(f)
    f.close()

    k_size = config['k_size']
    read_length = config['read_length']
    batch_size = config['batch_size']
    stride = config['stride']
    hidden_size = config['hidden_size']
    batch_size = 1

    dataset = loader.get_data_set(n_files='all',read_length=read_length, batch_size=batch_size, k=k_size, stride=stride, embedding="dict", embed_size=None, drop_last=False)
    list_ids = loader.get_data_set_ids(n_files='all',read_length=read_length, batch_size=batch_size, k=k_size, stride=stride, embedding="dict", embed_size=None, drop_last=False)

    (train_loader,train_idx), (validation_loader,val_idx), (test_loader,test_idx) = split_sets(dataset,batch_size,ids=True)
    indices_validation_set = [list_ids[i] for i in val_idx]
    dataframe_result = predictions_validation(validation_loader, model, indices_validation_set, batch_size,hidden_size, k_size, read_length)
    dataframe_result['gene'] = dataframe_result['id'].str.split('-', n = 1, expand = True)[0]
    dataframe_result['read'] = dataframe_result['id'].str.split('-', n = 1, expand = True)[1]
    return dataframe_result

# %%
def predictions_validation(validation_loader,model,indices,batch_size,hidden_size,k_size,read_length):
    output_labels = 2
    df = pd.DataFrame(columns=['id', 'predicted_values', 'true_values'])
    with torch.no_grad(): 
        model.eval()
        hidden = model.initHidden(batch_size,hidden_size)
        id_read = None
        prediction_batch = []
        ytrue_batch = []
        init = True
        for b, (x, y) in enumerate(validation_loader):
            x = x.type(torch.LongTensor)
            y = y.type(torch.LongTensor)
            x, y = x.to(device), y.to(device)
            out,hidden = model(hidden,x)
            
            y = y.view(-1, 1).repeat(1, k_size).view(batch_size,-1)
            y = get_original(y,k_size,1)
            out = out.view(read_length,batch_size,output_labels).exp()
            _, out_index= torch.max(out,dim=-1)
            out_index = out_index.view(-1, 1).repeat(1, k_size).view(batch_size,-1)
            
            out_index = get_original(out_index,k_size,1)
            
            if id_read == indices[b*batch_size: (b+1)*batch_size][0]:
                
                prediction_batch = prediction_batch + out_index
                ytrue_batch = ytrue_batch + y
                
            else:
                if not init:
                    df = df.append({'id' : id_read , 'predicted_values' : prediction_batch,'true_values':ytrue_batch} , ignore_index=True)
                prediction_batch = out_index
                ytrue_batch = y
                init = False
            id_read = indices[b*batch_size: (b+1)*batch_size][0]
        return df

# %%
def get_original(predictions,k_size=3,stride=1):
    i=0
    result = []
    while (i+k_size-1) < predictions.size()[1]:
        preds = predictions[0,i*stride:(i+k_size)*(stride)]
        preds = preds.tolist() 
        if i==0:
            result = result + preds
        else:
            result.append(preds[k_size-1])
        i = i + k_size 
    return result

# %%
def get_predictions_models():
    models = ['model1', 'model2', 'model3', 'model4', 'model5', 'model6']
    folders_for_k = ['models_grid/', 'models_k5/','models_k7/']
    epochs_values = [100]
    df_aggregated = pd.DataFrame(columns=['prediction_values','true_values','model','epoch'])
    for folder in folders_for_k:
        for model in models:
            for e in epochs_values:
                print('Folder: ', folder, 'Model: ', model, 'Epoch: ', e, datetime.datetime.now())
                dataframe_result = get_results_formatted(folder,model,e)
                df_aggregated = df_aggregated.append({'prediction_values': dataframe_result.predicted_values.sum(), 'true_values': dataframe_result.true_values.sum(),
                      'model': model+'_'+folder,'epoch': e }, ignore_index=True)
    
    df_aggregated.to_pickle('final_predictions.pkl')
    return df_aggregated

# %%
def encode_predictions(read_ids, predicted, save=False):
    
    reading_gene = False
    start = 0
    end = 0
    gene_size = 0
    starts = []
    ends = []
    intervals = []
    sizes = []
    ids = [] 
    
    for i, p in enumerate(predicted):
        if reading_gene:
            if p == 0:
                reading_gene = False
                end = i
                starts.append(start)
                ends.append(end)
                intervals.append('['+str(start)+', '+str(end)+')')
                sizes.append(gene_size)
                ids.append(read_ids[i])
            else:
                gene_size += 1      
        else:
            if p == 1:
                reading_gene = True
                start = i

    if predicted[len(predicted) - 1] == 1:
        end = i + 1
        intervals.append('['+str(start)+', '+str(end)+')')
        starts.append(start)
        ends.append(end)
        sizes.append(gene_size)
        ids.append(read_ids[i])
        
    out = pd.DataFrame({'Read number': ids, \
              'Strand': 1, \
              'Location of the gene in the read': intervals, \
              'Read length': sizes, \
              'Start': starts, \
              'End': ends})
    if save:
        out.to_csv('evaluation_dataframes/' + read_ids[0].split('-')[0] + '.csv')
        
    return out

# %%
dataframe_aggregated = get_predictions_models()
# Out:
# Folder:  models_grid/ Model:  model1 Epoch:  100 2019-07-06 12:44:33.596916
# model1_100
# Folder:  models_grid/ Model:  model2 Epoch:  100 2019-07-06 12:50:42.128905
# model2_100
# Folder:  models_grid/ Model:  model3 Epoch:  100 2019-07-06 12:56:22.205868
# model3_100
# Folder:  models_grid/ Model:  model4 Epoch:  100 2019-07-06 13:02:01.645853
# model4_100
# Folder:  models_grid/ Model:  model5 Epoch:  100 2019-07-06 13:07:46.766093
# model5_100
# Folder:  models_grid/ Model:  model6 Epoch:  100 2019-07-06 13:16:20.668554
# model6_100
# Folder:  models_k5/ Model:  model1 Epoch:  100 2019-07-06 13:24:48.667629
# model1_100
# Folder:  models_k5/ Model:  model2 Epoch:  100 2019-07-06 13:31:01.511829
# model2_100
# Folder:  models_k5/ Model:  model3 Epoch:  100 2019-07-06 13:37:02.158192
# model3_100
# Folder:  models_k5/ Model:  model4 Epoch:  100 2019-07-06 13:43:28.855754
# model4_100
# Folder:  models_k5/ Model:  model5 Epoch:  100 2019-07-06 13:48:38.689605
# model5_100
# Folder:  models_k5/ Model:  model6 Epoch:  100 2019-07-06 13:55:36.176635
# model6_100
# Folder:  models_k7 Model:  model1 Epoch:  100 2019-07-06 14:02:33.565723
# model1_100
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-4dace666d6a9> in <module>
# ----> 1 dataframe_aggregated = get_predictions_models()
#
# <ipython-input-7-16f17e8366e8> in get_predictions_models()
#       8             for e in epochs_values:
#       9                 print('Folder: ', folder, 'Model: ', model, 'Epoch: ', e, datetime.datetime.now())
# ---> 10                 dataframe_result = get_results_formatted(folder,model,e)
#      11                 df_aggregated = df_aggregated.append({'prediction_values': dataframe_result.predicted_values.sum(), 'true_values': dataframe_result.true_values.sum(),
#      12                       'model': model+'_'+folder,'epoch': e }, ignore_index=True)
#
# <ipython-input-10-929a377358a7> in get_results_formatted(folder, model_name, epoch)
#       3     model_selected = model_name+'_'+str(epoch)
#       4     print(model_selected)
# ----> 5     model = torch.load(folder + model_selected,map_location='cpu')
#       6     loader = PhageLoader("data/")
#       7
#
# ~/miniconda3/envs/cyberenv/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     380             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     381         new_fd = True
# --> 382         f = open(f, 'rb')
#     383     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     384         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models_k7model1_100'

# %%
available_genes = dataframe_result.gene.unique()
total = 0
for gene in available_genes:
    filtered_df = dataframe_result[dataframe_result['gene'] == gene]
    out_frames = []
    for k, r in filtered_df.iterrows():
        predicted = r['predicted_values']
        id_ = r['id']

        temp = encode_predictions([id_ for i in range(len(predicted))], predicted,save=False) 
        total += temp.shape[0]
        out_frames.append(temp)
    out = pd.concat(out_frames)
    out.to_csv('evaluation_dataframes/' + gene + '.csv')
print(total)
# Out:
# 6676

# %% [markdown]
# ## Configurations dataframe

# %%
models = ['model1', 'model2', 'model3', 'model4', 'model5', 'model6']
folders_for_k = ['models_grid/', 'models_k5/', 'models_k7/']
#folder = 'models_grid/'
configurations = []

for folder in folders_for_k:
    for model in models:
        configuration = model +'.json'
        f = open(folder + configuration)
        config = json.load(f)
        config['folder_to_look'] = folder
        config['loss_train_file_name'] = 'losses_train' + model[len(model)-1]
        config['loss_validation_file_name'] = 'losses_validation' + model[len(model)-1]
        config['base_prediction_name'] = model
        configurations.append(config)
        f.close()

configurations_df = pd.DataFrame(configurations)

# %%
configurations_df
# Out:
#    base_prediction_name  batch_size folder_to_look  hidden_size  k_size  \
# 0                model1          20   models_grid/           30       3
# 1                model2          20   models_grid/           30       3
# 2                model3          20   models_grid/           30       3
# 3                model4          20   models_grid/           30       3
# 4                model5          20   models_grid/           30       3
# 5                model6          20   models_grid/           30       3
# 6                model1          20     models_k5/           30       5
# 7                model2          20     models_k5/           30       5
# 8                model3          20     models_k5/           30       5
# 9                model4          20     models_k5/           30       5
# 10               model5          20     models_k5/           30       5
# 11               model6          20     models_k5/           30       5
# 12               model1          20     models_k7/           30       7
# 13               model2          20     models_k7/           30       7
# 14               model3          20     models_k7/           30       7
# 15               model4          20     models_k7/           30       7
# 16               model5          20     models_k7/           30       7
# 17               model6          20     models_k7/           30       7
#
#    loss_train_file_name loss_validation_file_name    lr  number_of_layers  \
# 0         losses_train1        losses_validation1  0.07                 1
# 1         losses_train2        losses_validation2  0.07                 1
# 2         losses_train3        losses_validation3  0.30                 1
# 3         losses_train4        losses_validation4  0.30                 1
# 4         losses_train5        losses_validation5  0.07                 2
# 5         losses_train6        losses_validation6  0.07                 2
# 6         losses_train1        losses_validation1  0.07                 1
# 7         losses_train2        losses_validation2  0.07                 1
# 8         losses_train3        losses_validation3  0.30                 1
# 9         losses_train4        losses_validation4  0.30                 1
# 10        losses_train5        losses_validation5  0.07                 2
# 11        losses_train6        losses_validation6  0.07                 2
# 12        losses_train1        losses_validation1  0.07                 1
# 13        losses_train2        losses_validation2  0.07                 1
# 14        losses_train3        losses_validation3  0.30                 1
# 15        losses_train4        losses_validation4  0.30                 1
# 16        losses_train5        losses_validation5  0.07                 2
# 17        losses_train6        losses_validation6  0.07                 2
#
#    optimizer  read_length  stride
# 0        SGD          100       1
# 1       ADAM          100       1
# 2        SGD          100       1
# 3       ADAM          100       1
# 4        SGD          100       1
# 5       ADAM          100       1
# 6        SGD          100       1
# 7       ADAM          100       1
# 8        SGD          100       1
# 9       ADAM          100       1
# 10       SGD          100       1
# 11      ADAM          100       1
# 12       SGD          100       1
# 13      ADAM          100       1
# 14       SGD          100       1
# 15      ADAM          100       1
# 16       SGD          100       1
# 17      ADAM          100       1

# %% [markdown]
# ## Charts for losses

# %%
import itertools
selected_hypers = ['lr', 'optimizer']
hyper_condigurations = list(itertools.product(*[list(configurations_df[h].unique()) for h in selected_hypers]))
values_per_configuration = []
print(hyper_condigurations)

for i, h_values in enumerate(hyper_condigurations):
    
    df_filters = [configurations_df[h] == h_values[j] for j, h in enumerate(selected_hypers)]
    df_filter = np.bitwise_and.reduce(df_filters, 0)

    losses_list = []
    models_to_evaluate = configurations_df[df_filter]
    for k, v in models_to_evaluate.iterrows():  
        folder = v['folder_to_look'] + v['loss_validation_file_name'] + '.pkl'
        losses = pickle.load(open(folder, 'rb'))
        losses_list.append(losses)        

    values_per_configuration.append(np.array(losses_list).T)
# Out:
# [(0.07, 'SGD'), (0.07, 'ADAM'), (0.3, 'SGD'), (0.3, 'ADAM')]

# %%
# chart for losses
hfont = {'fontfamily': 'sans-serif','fontname':'Helvetica', 'fontweight':'bold', 'fontsize': 45, 'color':'#2c3e50'}
sns.set()
sns.set_context("poster") # also notebook
sns.set_style('whitegrid',{'xtick.bottom': True,\
                           'ytick.left': True, \
                           'axes.edgecolor': '.1',\
                          'grid.linestyle': ''}) # ticks, whitegrid
#sns.axes_style()
f, axes = plt.subplots(1, figsize=(23,14))
for i, h_value in enumerate(hyper_condigurations):
    chart_data = values_per_configuration[i].mean(axis=1)
    sns.lineplot(x=list(range(100)), y=chart_data, label=h_value, ax=axes, linewidth=6)

axes.legend(loc='upper right', shadow=True, ncol=2)
axes.set_ylabel('Loss', fontsize=30)
axes.set_xlabel('Epochs', fontsize=30)
f.suptitle('Average Loss per Epoch for Models: \n (' + ', '.join(selected_hypers) + ')', **hfont)
plt.savefig('/Users/chadepl/Downloads/test.jpeg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Charts for other metrics

# %%
def generate_metrics():
    directories = ['models_grid/final_predictions.pkl','models_k5/final_predictions.pkl','models_k7/final_predictions.pkl']
    k = {'models_grid/final_predictions.pkl':3, 
         'models_k5/final_predictions.pkl':5,
         'models_k7/final_predictions.pkl':7}
    answer_df = pd.DataFrame(columns = ['base_prediction_name','batch_size','folder_to_look','hidden_size','k_size','loss_train_file_name','loss_validation_file_name',
 'lr','number_of_layers','optimizer','read_length','stride','epoch','accuracy','precision','recall','f1','tp','tn','fp','fn'])
    for directory in directories:
        
        df_evaluations = pickle.load(open(directory, 'rb'))
        metrics = pd.DataFrame(columns=['accuracy','precision','recall','f1','tp','tn','fp','fn','auc'])
        for index, row in df_evaluations.iterrows():
            predictions = row['prediction_values'] 
            true_values = row['true_values']
            tn, fp, fn, tp = confusion_matrix( true_values, predictions).ravel()
            fpr, tpr, thresholds = roc_curve(true_values, predictions)
            metrics = metrics.append({'accuracy': accuracy_score(true_values,predictions), 'precision': precision_score(true_values,predictions),
                              'recall': recall_score(true_values,predictions),'f1': f1_score(true_values,predictions),
                                     'tp':tp,'tn':tn, 'fp':fp, 'fn':fn,'auc':auc(fpr, tpr)}, ignore_index=True)
        final_df = pd.concat([df_evaluations,metrics],axis=1)
        final_df['k_size'] = k[directory]
        final_df['model']= final_df['model'].str.split('_', n = 1, expand = True)[0]
        final_df.rename(columns={'model':'base_prediction_name'}, inplace=True)
        
        final_df = pd.merge(configurations_df,final_df,how='inner',on=['base_prediction_name','k_size'])
        final_df=final_df.drop(['true_values','prediction_values'],axis=1)
        answer_df = pd.concat([answer_df,final_df])
    return answer_df

# %%
data_box = generate_metrics()
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
data_box.columns
# Out:
# Index(['accuracy', 'auc', 'base_prediction_name', 'batch_size', 'epoch', 'f1',
#        'fn', 'folder_to_look', 'fp', 'hidden_size', 'k_size',
#        'loss_train_file_name', 'loss_validation_file_name', 'lr',
#        'number_of_layers', 'optimizer', 'precision', 'read_length', 'recall',
#        'stride', 'tn', 'tp'],
#       dtype='object')

# %%
chart_data_box = data_box.copy()
selected_hypers = ['number_of_layers']
hyper_condigurations = list(itertools.product(*[list(chart_data_box[h].unique()) for h in selected_hypers]))
values_per_configuration = []
print(hyper_condigurations)
chart_data_box['hyper_configuration'] = 0

for i, h_values in enumerate(hyper_condigurations):
    
    df_filters = [chart_data_box[h] == h_values[j] for j, h in enumerate(selected_hypers)]
    df_filter = np.bitwise_and.reduce(df_filters, 0)
    models_of_configuration = chart_data_box[df_filter]

    chart_data_box.loc[df_filter, 'hyper_configuration'] = ', '.join(str(v) for v in h_values)


chart_data_box_melted = pd.melt(chart_data_box.loc[:, ['hyper_configuration', 'accuracy', 'precision', 'recall', 'f1', 'auc']], \
        id_vars=['hyper_configuration'], value_vars=['accuracy', 'precision', 'recall', 'f1', 'auc'])

hfont = {'fontfamily': 'sans-serif','fontname':'Helvetica', 'fontweight':'bold', 'fontsize': 45, 'color':'#2c3e50'}
sns.set()
sns.set_context("poster") # also notebook
sns.set_style('whitegrid',rc={'xtick.bottom': True,\
                           'ytick.left': True, \
                           'axes.edgecolor': '.1',\
                          'grid.linestyle': ''}) # ticks, whitegrid

f, axes = plt.subplots(1, figsize=(23,14))
sns.boxplot(x="variable", y="value", hue="hyper_configuration", data=chart_data_box_melted, ax=axes)

axes.tick_params(axis='x', labelsize=35)
axes.legend(loc='lower right', shadow=True, ncol=2, title='(' + ','.join(selected_hypers) + ')')
axes.set_ylabel('')
axes.set_xlabel('')
f.suptitle('Metric Comparison: (' + ', '.join(selected_hypers) + ')', **hfont)
plt.savefig('/Users/chadepl/Downloads/test.jpeg', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1c455f36e928> in <module>
# ----> 1 chart_data_box = data_box.copy()
#       2 selected_hypers = ['number_of_layers']
#       3 hyper_condigurations = list(itertools.product(*[list(chart_data_box[h].unique()) for h in selected_hypers]))
#       4 values_per_configuration = []
#       5 print(hyper_condigurations)
#
# NameError: name 'data_box' is not defined

# %%
chart_data_box
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-91d8a01bb4d1> in <module>
# ----> 1 chart_data_box
#
# NameError: name 'chart_data_box' is not defined

# %%
# chart for losses

#sns.axes_style()
f, axes = plt.subplots(1, figsize=(23,14))
for i, h_value in enumerate(hyper_condigurations):
    chart_data = values_per_configuration[i].mean(axis=1)
    sns.lineplot(x=list(range(100)), y=chart_data, label=h_value, ax=axes, linewidth=6)

axes.legend(loc='upper right', shadow=True, ncol=2)
axes.set_ylabel('Loss', fontsize=30)
axes.set_xlabel('Epochs', fontsize=30)
f.suptitle('Average Loss per Epoch for Models: \n (' + ', '.join(selected_hypers) + ')', **hfont)
plt.savefig('/Users/chadepl/Downloads/test.jpeg', dpi=300, bbox_inches='tight')

# %%
dataframe_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-17894830c763> in <module>()
# ----> 1 dataframe_result
#
# NameError: name 'dataframe_result' is not defined
